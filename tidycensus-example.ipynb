# %% [markdown]
# ## Setup

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## TidyCensus Example
#
# This notebook grabs data from the US Census using the [tidycensus package in R](https://walker-data.com/tidycensus/index.html). Make sure you have installed the `tidyverse` and `tidycensus` packages.

# %%
# %%R
#
# library(tidycensus)
# library(tidyverse)
#
# # store any shapefiles we grab from the census in ~/Library/Caches/tigris
# # in case the government removes the shapefiles FTP server again 😭
# options(tigris_use_cache = TRUE)

# %% [markdown]
# ### Step 1 \| Load Census API key from `.env` file
#
# The `.env` file should look like this:
#
# ```bash
# CENSUS_API_KEY="your-api-key-here"
# ```
#
# This is what is known as an environment variable.
#
# We load it below in Python

# %%
from dotenv import load_dotenv
load_dotenv() # <- searches for a file named .env and loads the environment variables in it
# Out:
# True

# %% [markdown]
# And in this cell we pass the environment variable to tidycensus in R

# %%
# %%R
#
# census_api_key(Sys.getenv("CENSUS_API_KEY")) # <- Loads CENSUS_API_KEY from environment variable and sets it in R
# Out:
# To install your API key for use in future sessions, run this function with `install = TRUE`.

# %% [markdown]
# ### Step 2 \| Figure out what tables you want data from and at what geographic granularity
#
# Use <https://censusreporter.org/> to figure out which tables you want.
#
# -   Scroll to the bottom of the page to see the tables.
# -   If you already know the table ID, stick that in the "Explore" section to learn more about that table.
#
# Once you've found the variable or variables you want, you can plug them into this code under `variables`.

# %%
# %%R
#
# # the variable B01003_001 was selectd from the census table
# # for population, which we found in censusreporter here:
# # https://censusreporter.org/tables/B01003/
#
# # Here are the various geographies you can use with tidycensus
# # https://walker-data.com/tidycensus/articles/basic-usage.html#geography-in-tidycensus
#
# # Get variable from ACS
# nyc_census_data <- get_acs(geography = "tract",
#                       state='NY',
#                       county = c("New York", "Kings", "Queens", "Bronx", "Richmond"),
#                       variables = c(
#                         population="B01003_001",     # population
#                         total_units = "B25001_001",  # housing units
#                         med_inc="B19013_001",         # median income
#                         vision_difficulty = "B18103_001"
#                       ),
#                       year = 2021,
#                       survey="acs5",
#                       geometry=T)
#
# nyc_census_data
# Out:
# Simple feature collection with 9308 features and 5 fields (with 4 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# First 10 features:
#          GEOID                                       NAME          variable
# 1  36081014700  Census Tract 147, Queens County, New York        population
# 2  36081014700  Census Tract 147, Queens County, New York vision_difficulty
# 3  36081014700  Census Tract 147, Queens County, New York           med_inc
# 4  36081014700  Census Tract 147, Queens County, New York       total_units
# 5  36047058400   Census Tract 584, Kings County, New York        population
# 6  36047058400   Census Tract 584, Kings County, New York vision_difficulty
# 7  36047058400   Census Tract 584, Kings County, New York           med_inc
# 8  36047058400   Census Tract 584, Kings County, New York       total_units
# 9  36061006900 Census Tract 69, New York County, New York        population
# 10 36061006900 Census Tract 69, New York County, New York vision_difficulty
#    estimate   moe                       geometry
# 1      2863   513 MULTIPOLYGON (((-73.9137 40...
# 2      2863   513 MULTIPOLYGON (((-73.9137 40...
# 3     71815 18034 MULTIPOLYGON (((-73.9137 40...
# 4      1570   213 MULTIPOLYGON (((-73.9137 40...
# 5      3655   529 MULTIPOLYGON (((-73.96103 4...
# 6      3655   529 MULTIPOLYGON (((-73.96103 4...
# 7     67315 10294 MULTIPOLYGON (((-73.96103 4...
# 8      1498   167 MULTIPOLYGON (((-73.96103 4...
# 9      2450   372 MULTIPOLYGON (((-74.02064 4...
# 10     2450   372 MULTIPOLYGON (((-74.02064 4...
# Getting data from the 2017-2021 5-year ACS
# Using FIPS code '36' for state 'NY'
# Using FIPS code '061' for 'New York County'
# Using FIPS code '047' for 'Kings County'
# Using FIPS code '081' for 'Queens County'
# Using FIPS code '005' for 'Bronx County'
# Using FIPS code '085' for 'Richmond County'

# %% [markdown]
# ### Step 3 | Pivot to Wide Format
#
# Pivot from long to wide using `pivot_wider`.
#
# Depending on what you're trying to do, you may want the data in long or wide format. This example pivots the data to wide format, which will help us with mapping later on in the notebook.

# %%
# %%R
#
# nyc_census_data <- nyc_census_data %>%
#   # pivot from wide to long
#   pivot_wider(
#     names_from=variable,
#     values_from = c(estimate, moe),
#     names_glue = "{variable}_{.value}"
#   )
#
# nyc_census_data
# Out:
# Simple feature collection with 2327 features and 10 fields (with 1 geometry empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 2,327 × 11
#    GEOID       NAME                                 geometry population_estimate
#    <chr>       <chr>                      <MULTIPOLYGON [°]>               <dbl>
#  1 36081014700 Census Tract 147, … (((-73.9137 40.76548, -7…                2863
#  2 36047058400 Census Tract 584, … (((-73.96103 40.59616, -…                3655
#  3 36061006900 Census Tract 69, N… (((-74.02064 40.73039, -…                2450
#  4 36047073000 Census Tract 730, … (((-73.93345 40.6257, -7…                2676
#  5 36047100400 Census Tract 1004,… (((-73.90735 40.63083, -…                3004
#  6 36047055700 Census Tract 557, … (((-73.96279 40.72256, -…                1834
#  7 36005022101 Census Tract 221.0… (((-73.92012 40.83759, -…                4030
#  8 36081047000 Census Tract 470, … (((-73.78059 40.71343, -…                3637
#  9 36047050402 Census Tract 504.0… (((-73.97496 40.6478, -7…                1758
# 10 36047028501 Census Tract 285.0… (((-73.94439 40.70043, -…                 356
# # ℹ 2,317 more rows
# # ℹ 7 more variables: vision_difficulty_estimate <dbl>, med_inc_estimate <dbl>,
# #   total_units_estimate <dbl>, population_moe <dbl>,
# #   vision_difficulty_moe <dbl>, med_inc_moe <dbl>, total_units_moe <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R
#
# nyc_census_data %>% select(NAME, vision_difficulty_estimate)
# Out:
# Simple feature collection with 2327 features and 2 fields (with 1 geometry empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 2,327 × 3
#    NAME                         vision_difficulty_es…¹                  geometry
#    <chr>                                         <dbl>        <MULTIPOLYGON [°]>
#  1 Census Tract 147, Queens Co…                   2863 (((-73.9137 40.76548, -7…
#  2 Census Tract 584, Kings Cou…                   3655 (((-73.96103 40.59616, -…
#  3 Census Tract 69, New York C…                   2450 (((-74.02064 40.73039, -…
#  4 Census Tract 730, Kings Cou…                   2676 (((-73.93345 40.6257, -7…
#  5 Census Tract 1004, Kings Co…                   3004 (((-73.90735 40.63083, -…
#  6 Census Tract 557, Kings Cou…                   1834 (((-73.96279 40.72256, -…
#  7 Census Tract 221.01, Bronx …                   4030 (((-73.92012 40.83759, -…
#  8 Census Tract 470, Queens Co…                   3637 (((-73.78059 40.71343, -…
#  9 Census Tract 504.02, Kings …                   1758 (((-73.97496 40.6478, -7…
# 10 Census Tract 285.01, Kings …                    344 (((-73.94439 40.70043, -…
# # ℹ 2,317 more rows
# # ℹ abbreviated name: ¹​vision_difficulty_estimate
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ### Step 4 | Do calculations with `mutate`
#
# In R, you can use `mutate` to create new columns or modify existing ones.
#
# In this example, we create a column called `borough` by extracting the borough from the `NAME` column.
#
# _(hint, I used GitHub Copilot -- a tool similar to ChatGPT -- to do this...see my prompt in the comments)_

# %%
# %%R
#
# # Extract borough name from NAME by splitting strings like
# # "Census Tract 147, Queens County, New York"
# # on commas and extracting the second to last element
# # Block Group 2, Census Tract 934.01, Queens County, New York
#
# nyc_census_data <- nyc_census_data %>%
#     mutate(
#         borough = str_split(NAME, ",") %>% map_chr(2) %>% str_trim(),
#         vision_difficulty_pct = vision_difficulty_estimate / population_estimate
#
#     )

# %%
# %%R
# nyc_census_data %>%
#     select(NAME, vision_difficulty_estimate, population_estimate)
# Out:
# Simple feature collection with 2327 features and 3 fields (with 1 geometry empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 2,327 × 4
#    NAME     vision_difficulty_es…¹ population_estimate                  geometry
#    <chr>                     <dbl>               <dbl>        <MULTIPOLYGON [°]>
#  1 Census …                   2863                2863 (((-73.9137 40.76548, -7…
#  2 Census …                   3655                3655 (((-73.96103 40.59616, -…
#  3 Census …                   2450                2450 (((-74.02064 40.73039, -…
#  4 Census …                   2676                2676 (((-73.93345 40.6257, -7…
#  5 Census …                   3004                3004 (((-73.90735 40.63083, -…
#  6 Census …                   1834                1834 (((-73.96279 40.72256, -…
#  7 Census …                   4030                4030 (((-73.92012 40.83759, -…
#  8 Census …                   3637                3637 (((-73.78059 40.71343, -…
#  9 Census …                   1758                1758 (((-73.97496 40.6478, -7…
# 10 Census …                    344                 356 (((-73.94439 40.70043, -…
# # ℹ 2,317 more rows
# # ℹ abbreviated name: ¹​vision_difficulty_estimate
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ### Step 5 | Example Plots
#
# Let's practice with histograms

# %%
# %%R -w 1000
#
# ggplot(nyc_census_data) +
#     aes(x=vision_difficulty_pct) +
#     geom_histogram() +
#     facet_wrap(~borough)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 88 rows containing non-finite outside the scale range (`stat_bin()`).

# %%
# %%R -w 1000 -h 600
#
# ggplot(nyc_census_data) +
#     aes(x=vision_difficulty_pct, y=borough) +
#     geom_jitter(alpha=0.5) +
#     # overlay a box and whisker plot that is transparent with no outliers and is red
#     geom_boxplot(fill=NA, outlier.shape=NA, color="red")
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1: Removed 88 rows containing non-finite outside the scale range
# (`stat_boxplot()`).
#
# R[write to console]: 2: Removed 88 rows containing missing values or values outside the scale range
# (`geom_point()`).

# %% [markdown]
# ### Step 6 \| Example Map
#
# See more details about making maps here:
#
# https://walker-data.com/tidycensus/articles/spatial-data.html

# %%
# %%R
#
# library(tigris)
#
# # remove water from the shapefiles
# # https://walker-data.com/tidycensus/articles/spatial-data.html
# nyc_census_data <- nyc_census_data %>%
#     erase_water()
# Out:
# Fetching area water data for your dataset's location...
# Erasing water area...
# If this is slow, try a larger area threshold value.

# %%
# %%R -w 1000 -h 1000
#
# nyc_census_data %>%
#   ggplot(aes(fill = med_inc_estimate)) +
#   geom_sf(color = NA) +
#   scale_fill_gradient(low="white", high="red") +
#   labs(
#     title = "TKTK",
#     subtitle = "Median Income by Census Tract, New York City",
#     caption = "Source: US Census Bureau"
#   )

# %% [markdown]
# ## Step 7 | Your Turn - Pick a different geography
#
# - 👉 Here are the various [geographies you can use with tidycensus](https://walker-data.com/tidycensus/articles/basic-usage.html#geography-in-tidycensus). Try changing the analysis from the census tract level to the something more granular like `block group`. What do you notice that you didn't when looking at the tract-level data?
#
#     **hint**: If you select block group, you may have to modify the code in **step 5**
#     >
#     > When you ask for **census tracts**, the NAME variable looks like this `Census Tract 147, Queens County, New York`
#     >
#     > The code in step 5 is currently set up to split on commas and take the second item (in this case `Queens County`).
#     >
#     > ```r
#     >   nyc_census_data <- nyc_census_data %>%
#     >        mutate(
#     >        borough = str_split(NAME, ",") %>% map_chr(3) %>% str_trim(),
#     >    )
#     >
#     >    nyc_census_data
#     >```
#     >
#     >But when you ask for data by **block group**, the `NAME` variable looks like this `Block Group 0, Census Tract 135.02, New York County, New York`.
#     >
#     >So you will have to modify the code to extract the borough from the **block group** rather than the **census tract** name.
#
#
# ## Step 8 | Your Turn - Explore: Pick a your own variable or variables and geography level
#
#
# - 👉 Pick a different variable other than median income and re-run the notebook. Use [https://censusreporter.org/](https://censusreporter.org) figure out what variable or variables you'd like to explore and add them to the list in **step 2**.
#
#
#     *hint*: Remember, you can create new columns in **step 5** using `mutate`. For example, the following code would both split the census tract out of the NAME column, and also
#
#     ```r
#     nyc_census_data <- nyc_census_data %>%
#         mutate(
#             borough = str_split(NAME, ",") %>% map_chr(2) %>% str_trim(),
#             units_per_person = total_unitstotal_units_estimate / population_estimate
#         )
#
#     nyc_census_data
#     ```

# %% [markdown]
# -  👉 Describe the output, what questions does this raise for you?

# %%
# %%R
# nyc_census_data <- get_acs(geography = "block group",
#                       state='NY',
#                       county = c("New York", "Kings", "Queens", "Bronx", "Richmond"),
#                       variables = c(
#                         population="B01003_001",     # population
#                         total_units = "B25001_001",  # housing units
#                         med_inc="B19013_001"         # median income
#                       ),
#                       year = 2021,
#                       survey="acs5",
#                       geometry=T)
#
# nyc_census_data
# Out:
# Simple feature collection with 20421 features and 5 fields (with 147 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# First 10 features:
#           GEOID                                                          NAME
# 1  360810934012   Block Group 2, Census Tract 934.01, Queens County, New York
# 2  360810934012   Block Group 2, Census Tract 934.01, Queens County, New York
# 3  360810934012   Block Group 2, Census Tract 934.01, Queens County, New York
# 4  360610135020 Block Group 0, Census Tract 135.02, New York County, New York
# 5  360610135020 Block Group 0, Census Tract 135.02, New York County, New York
# 6  360610135020 Block Group 0, Census Tract 135.02, New York County, New York
# 7  360050516012    Block Group 2, Census Tract 516.01, Bronx County, New York
# 8  360050516012    Block Group 2, Census Tract 516.01, Bronx County, New York
# 9  360050516012    Block Group 2, Census Tract 516.01, Bronx County, New York
# 10 360610150011 Block Group 1, Census Tract 150.01, New York County, New York
#       variable estimate   moe                       geometry
# 1   population     1183   379 MULTIPOLYGON (((-73.844 40....
# 2      med_inc    82000 22962 MULTIPOLYGON (((-73.844 40....
# 3  total_units      534   123 MULTIPOLYGON (((-73.844 40....
# 4   population        0    13 MULTIPOLYGON (((-74.00162 4...
# 5      med_inc       NA    NA MULTIPOLYGON (((-74.00162 4...
# 6  total_units        0    13 MULTIPOLYGON (((-74.00162 4...
# 7   population      887   289 MULTIPOLYGON (((-73.79188 4...
# 8      med_inc   118514 31053 MULTIPOLYGON (((-73.79188 4...
# 9  total_units      511   153 MULTIPOLYGON (((-73.79188 4...
# 10  population      984   339 MULTIPOLYGON (((-73.95881 4...
# Getting data from the 2017-2021 5-year ACS
# Using FIPS code '36' for state 'NY'
# Using FIPS code '061' for 'New York County'
# Using FIPS code '047' for 'Kings County'
# Using FIPS code '081' for 'Queens County'
# Using FIPS code '005' for 'Bronx County'
# Using FIPS code '085' for 'Richmond County'

# %% [markdown]
# -  👉 Do your conclusions or questions change if you pick a different geography?

# %%
# answer here
